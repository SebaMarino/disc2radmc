# %% [markdown]
# # Make gas emission cubes
# In this tutorial you will see how to use disc2radmc to create all the input files that radmc3d needs to run and how to run radmc3d to produce gas emission cubes. This is very similar to the case of dust. In fact, for the gas model we will have dust and gas.
#
# If you haven't already, it may be easier clone the github, as it includes files needed for the tutorial that will otherwise have to be downloaded. The paths in this tutorial will assume you are working with it within the filestructure of the repo

# %%
#!git clone https://github.com/SebaMarino/disc2radmc

# %%
import os
import numpy as np
import sys
sys.path.append("/data/cs1316/disc2radmc_models/disc2radmc")
import disc2radmc 
import matplotlib.pyplot as plt
import astropy.io.fits as pyfits

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# We start by defining what the surface density of dust and gas will be. These can be the same or different. For simplicity we will use the same. This is defined as a function that receives the cylindrical `r` and `phi` as the first arguments, followed by any argument that defines the surface density. This doesn't need to be normalized as that will be done internally for each dust species. This function must be able to receive ndarray's for r and phi.
#
# Below an example of a surface density that is a Gaussian radially, but varies azimuthally as sin(phi)

# %%
def Sigma_all(r, phi, rc, sigr):
    
    return np.exp( -0.5 * ((r-rc)/sigr)**2.)

# %% [markdown]
# We now define the parameters that will define our model. This is the same as the parameters for the dust only model, but with a few additional ones. These are the gas species (atoms, molecules, etc), their masses, stellar mass (which sets the gas velocity), etc. Note that many of these parameters don't need to be defined and they will be set to default values. However, it is better to know how to change these if your model is more complicated.
#
# For gas, you will need to download the cross sections of each gas species that you want to model. These can be found in https://home.strw.leidenuniv.nl/~moldata/, a few of which are in https://github.com/SebaMarino/disc2radmc/tree/main/opacities/gas

# %%
########################
###### PARAMETERS ######
########################

## STAR
## STAR
dpc=50.  # [pc] distance to source 
target='HDawesome'# name
Rstar=1.0 # [Solar radii]
Tstar= -5800 # [K] If this is negative, the code will consider the star as a blackbody. 
Mstar = 1.0
g=4.0
# For a realistic stellar model, you can download bt-settl models 
# from http://svo2.cab.inta-csic.es/theory/newov2/index.php and indicate their directory below
# dir_stellar_templates='/Users/Sebamarino/Astronomy/Stellar_templates/BT-Settl/bt-settl/'
# The code will then search for files named as 
# dir_stellar_templates+'lte%03i-%1.1f-0.0a+0.0.BT-NextGen.7.dat.txt'%(Tstar//100,g) if Tstar>=2600
# dir_stellar_templates+'lte%03i-%1.1f-0.0.BT-Settl.7.dat.txt'%(T//100,g)            else
# and interpolate models with neighbouring temperatures if necessary

## DUST
Mdust=0.5      # [Mearth] Total dust mass
rc=100.        # [au]
sigr=50.       # [au]
amin=1.0       # [mu]  minimum grain size (1 by default)
amax=1.0e4     # [mu]  maximum grain size (1e4 by default)
N_species=1    #  (1 by default) Number of dust size bins to use for the radiative transfer calculations. 
slope = -3.5   #  (-3.5 by default) Slope of the size distribution. This is used for computing opacities and for the mass distribution of each size bin
h=0.05         # vertical aspect ratio =H/r, where H is the vertical standard deviation. This is a constant, but other parametrizations are possible and will be shown below. 
par_sigma=(rc, sigr) # list containing the parameters that define the dust surface density. They must be in the same order as in the definition of Sigma_dust

## GAS
gas_species=['12c16o', 'catom'] # species. Each one of these must have a file named molecule_*.inp containing its cross sections. These can be downloaded from https://home.strw.leidenuniv.nl/~moldata/
Masses=np.array([1.0e-2, 1.0e-3 ]) # [Mearth] Total mass of each gas species
masses=np.array([28.*disc2radmc.mp, 12*disc2radmc.mp ]) # [g] molecular weight of each species
mu=28. # mean molecular weight. This could be = np.sum(masses*Masses)/np.sum(Msses)/np.disc2radmc.mp
turbulence=True
alpha_turb=1.0e-2

## MODEL SPATIAL GRID
rmin=10. # [au] make sure it is small enough to sample the surface density
rmax=300.# [au] 
Nr=50    # radial cells (linearly or logspaced)
Nphi=50 # azimuthal cells
Nth=50   # polar angle cells (per emisphere)
thmax=np.arctan(h)*10 # maximum polar angle to sample as measured from the midplane.
axisym=False # Consider the disc to be axisymmetric to speed up calculations? it can overwrite Nphi if True and set it to 1
mirror=True  # Mirror the upper half to speed up calculations. This is incompatible with anisotropic scattering. When including radial velocities in the gas, if the model is mirrored the channel maps appear wrong (not sure why).

logr=True # Sample r logarithmically or linearly

# WAVELENGTH GRID (grid to sample the stellar flux in temperature calculations, see radmc3d manual)
lammin=0.09  # [mu]  minimum wavelength to consider in our model (important for temperature calculation)
lammax=1.0e5 # [mu] minimum wavelength to consider in our model (important for temperature calculation)
Nlam=150     # number of cells logarithmically spaced to sample the wavelength range.

# IMAGE PARAMETERS
Npix=512  # number of pixels
dpix=0.03 # pixel size in arcsec
inc=45.    # inclination
PA=90.    # position angle

wavelength=880. # [um] image wavelength
scattering_mode=1 # scattering mode (0=no scattering, 1=isotropic, 2=anisotropic using H&G function)

# %% [markdown]
# Our model will be made of multiple objects that we need to define and save for radmc3d:
# - Spatial grid
# - Wavelength grid
# - Star
# - Dust
# - Gas

# %%
### PHYSICAL GRID
gridmodel=disc2radmc.physical_grid(rmin=rmin, rmax=rmax, Nr=Nr, Nphi=Nphi, Nth=Nth, thmax=thmax, mirror=mirror, logr=logr, axisym=axisym)
gridmodel.save()

### WAVELENGTH GRID
lammodel=disc2radmc.wavelength_grid(lammin=lammin, lammax=lammax, Nlam=Nlam)
lammodel.save()

### STAR
starmodel=disc2radmc.star(lammodel, Tstar=Tstar, Rstar=Rstar, Mstar=Mstar, g=g,
                               #dir_stellar_templates=dir_stellar_templates # necessary line if Tstar>0
                               )
starmodel.save()

# %% [markdown]
# For the dust, we will mix the optical constants of three species (astrosilicates, amorphous carbon and water ice) using the Bruggeman rule.

# %%
### DUST SIZE DISTRIBUTION AND OPACITY
# path to optical constants that can be found at
# https://github.com/SebaMarino/disc2radmc/tree/main/opacities/dust_optical_constants
path_opct = os.getcwd().split('docs')[0] + 'opacities/'
lnk_files=[path_opct+'dust_optical_constants/Sil_0.1_10000.lnk',
           path_opct+'dust_optical_constants/ac_opct.lnk',
           path_opct+'dust_optical_constants/ai_60K_0.1_10000.lnk']
densities=[4., 3., 1.] # densities in g/cm3
mass_weights=[70.0, 15., 15.] # mixing ratios by mass
dust=disc2radmc.dust(lammodel,
                           Mdust=Mdust,
                           lnk_file=lnk_files,
                           densities=densities,
                           N_species=N_species,
                           slope=slope,
                           N_per_bin=100, # number of species per size bin to have a good representation 
                           mass_weights=mass_weights,
                           tag='mix', # name to give to this new mixed species
                           compute_opct=True)
# Out:
# Compute average optical constants
# final density = 2.7 g/cm3

# %% [markdown]
# Now we will compute the opacity using the Mie theory by Craig F. Bohren and Donald R. Huffman.
#
# 1. If you haven't already cloned the disc2radmc repo, you will need to download the files at https://github.com/SebaMarino/disc2radmc/tree/main/opacities/Mie and compile them. You can compile them by uncommenting and running the cells below, or by
# opening a terminal, cd-ing into the folder where you downloaded the files and running `make`. That will create an executable file called `makeopac`
#
# 2. In order to compute the opacities, you will first need to copy `makeopac` into your working directory
#
# 3. Finally, run the cell below containing `dust.compute_opacities()` which will produce one or a set of files containing the opacities of the N_species dust species.
#
# **Note: This last step might take a while, so you probably want to comment that line after computing your final opacities.**

# %%
path_opct
# Out:
# '/data/cs1316/disc2radmc_models/disc2radmc/opacities/'

# %%
if not os.path.exists('makeopac'): #checks if makeopac is already in your working directory
    if os.path.isdir(path_opct+'Mie/thing'): #Confirms that the opacities/Mie directory exists
        if not os.path.exists(path_opct+'Mie/makeopac'):#checks if makeopac is in the Mie directory
            os.system(f'(cd {path_opct}Mie && make)') #runs 'make' to create makeopac
        os.system(f'cp {path_opct}Mie/makeopac .')# copies makeopac into your working direcotry
    else:
        print(f'Cannot find directory {path_opct}Mie')
        print("Please confirm you have the correct path to your opacities")

# %%
dust.compute_opacities()
# Out:
# rm: cannot remove './Tempkappa/*': No such file or directory
# rm: cannot remove './param.inp': No such file or directory

# %% [markdown]
# We now define our dust densities in each cell of the spatial grid and save this for radm3d.

# %%
### DUST DENSITY DISTRIBUTION
dust.dust_densities(grid=gridmodel,function_sigma=Sigma_all, par_sigma=par_sigma, h=h)
dust.write_density()

# %% [markdown]
# Normally, one would deine the gas before running radmc3d. However, we will include turbulence in our gas model, which is parametrised as a function of the temperature. Similarly, one could define a scale height based on the calculated temperature.
# ### So let's run radmc3d to compute the temperature
# We start by specifying some parameters for RADMC3D. We proceed computing the temperature with the thermal montecarlo simulation. Then we will compute an image, and finally an SED.

# %%
sim=disc2radmc.simulation(nphot=10000000, # number of photon packages for thermal monte carlo
                            nphot_scat=1000000, # number of photon packages for image
                            nphot_spec=10000,   # number of photon packages for spectrum
                            nphot_mono=10000,   # number of photon packages for the monochromatic monte carlo
                            scattering_mode=scattering_mode, 
                            incl_lines=1, # whether to include gas lines (1) or not (0)
                            modified_random_walk=0, # for very optically thick medium, this is a useful approximation
                            istar_sphere=0, # consider the star a sphere or a point.
                            tgas_eq_tdust=1, # gas temperature equal to the temperature of the first dust species
                            setthreads=4,
                            verbose=True, 
                               )

### RUN MCTHERM to compute temperature
sim.mctherm()
# Out:
#
#  ================================================================
#       WELCOME TO RADMC-3D: A 3-D CONTINUUM AND LINE RT SOLVER
#
#                           VERSION 2.0
#
#                 (c) 2008-2023 Cornelis Dullemond
#
#        Please feel free to ask questions. Also please report
#         bugs and/or suspicious behavior without hestitation.
#       The reliability of this code depends on your vigilance!
#                     dullemond@uni-heidelberg.de
#
#    To keep up-to-date with bug-alarms and bugfixes, follow the
#                      RADMC-3D code on github
#              https://github.com/dullemond/radmc3d-2.0
#
#               Please visit the RADMC-3D home page at
#   http://www.ita.uni-heidelberg.de/~dullemond/software/radmc-3d/
#  ================================================================
#
#  Number of processors:           96
#  Number of threads in use:            4
#  Note: T_gas taken to be equal to T_dust of dust species            1
#  Reading global frequencies/wavelengths...
#  Reading grid file and prepare grid tree...
#  Reading star data...
#  Note: Please be aware that you treat the star(s) as
#        point source(s) while using spherical coordinate mode.
#        Since R_*<<R_in this is probably OK, but if you want
#        to play safe, then set istar_sphere = 1 in radmc3d.inp.
#  Note: Star 1 is taken to be a blackbody star
#        at a temperature T = 5800. Kelvin
#  Grid information (current status):
#    We have 125000 branches, of which 125000 are actual grid cells.
#    ---> 100.000% mem use for branches, and 100.000% mem use for actual cells.
#    No grid refinement is active. The AMR tree is not allocated (this saves memory).
#  Reading the heat source spatial distribution...
#  Using mirror symmetry in equatorial plane, because max(theta)==pi/2.
#  NOTE: Lines are included in this model. But for the
#        thermal Monte Carlo run they are swithed off...
#  Beware: The OpenMP-parallel acceleration of RADMC-3D has
#          not yet been tested with all of the modes and
#          features that RADMC-3D offers. Please check
#          your parallel results against the serial version
#          (i.e. compiling without -fopenmp).
#  Reading dust data...
#  Reading dust densities...
#  Dust mass total =    1.5011221803833592E-006  Msun
#  Using dust scattering mode            1
#  Computing emissivity database...
#  Computing total input luminosities...
#  Modified Random Walk mode is switched OFF
#
#  Starting the thermal Monte Carlo simulation....
#  Thread Nr           0 of           4 threads in total
#  Thread Nr           3 of           4 threads in total
#  Thread Nr           1 of           4 threads in total
#  Thread Nr           2 of           4 threads in total
#  Thread:           2 Photon nr:                 1000
#  Thread:           3 Photon nr:                 2000
#  Thread:           3 Photon nr:                 3000
#  Thread:           1 Photon nr:                 4000
#  Thread:           3 Photon nr:                 5000
#  Thread:           3 Photon nr:                 6000
#  Thread:           2 Photon nr:                 7000
#  Thread:           2 Photon nr:                 8000
#  Thread:           2 Photon nr:                 9000
#  Thread:           2 Photon nr:                10000
#  Thread:           0 Photon nr:                11000
#  Thread:           1 Photon nr:                12000
#  Thread:           3 Photon nr:                13000
#  Thread:           3 Photon nr:                14000
#  Thread:           0 Photon nr:                15000
#  Thread:           0 Photon nr:                16000
#  Thread:           0 Photon nr:                17000
#  Thread:           0 Photon nr:                18000
#  Thread:           2 Photon nr:                19000
#  Thread:           1 Photon nr:                20000
#  Thread:           3 Photon nr:                21000
#  Thread:           2 Photon nr:                22000
#  Thread:           0 Photon nr:                23000
#  Thread:           3 Photon nr:                24000
#  Thread:           1 Photon nr:                25000
#  Thread:           2 Photon nr:                26000
#  Thread:           2 Photon nr:                27000
#  Thread:           1 Photon nr:                28000
#  Thread:           1 Photon nr:                29000
#  Thread:           3 Photon nr:                30000
#  Thread:           3 Photon nr:                31000
#  Thread:           1 Photon nr:                32000
#  Thread:           3 Photon nr:                33000
#  Thread:           2 Photon nr:                34000
#  Thread:           3 Photon nr:                35000
#  Thread:           2 Photon nr:                36000
#  Thread:           0 Photon nr:                37000
#  Thread:           0 Photon nr:                38000
#  Thread:           0 Photon nr:                39000
#  Thread:           2 Photon nr:                40000
#  Thread:           3 Photon nr:                41000
#  Thread:           0 Photon nr:                42000
#  Thread:           0 Photon nr:                43000
#  Thread:           3 Photon nr:                44000
#  Thread:           1 Photon nr:                45000
#  Thread:           0 Photon nr:                46000
#  Thread:           0 Photon nr:                47000
#  Thread:           1 Photon nr:                48000
#  Thread:           1 Photon nr:                49000
#  Thread:           2 Photon nr:                50000
#  Thread:           0 Photon nr:                51000
#  Thread:           1 Photon nr:                52000
#  Thread:           2 Photon nr:                53000
#  Thread:           2 Photon nr:                54000
#  Thread:           3 Photon nr:                55000
#  Thread:           0 Photon nr:                56000
#  Thread:           3 Photon nr:                57000
#  Thread:           3 Photon nr:                58000
#  Thread:           0 Photon nr:                59000
#  Thread:           3 Photon nr:                60000
#  Thread:           3 Photon nr:                61000
#  Thread:           1 Photon nr:                62000
#  Thread:           0 Photon nr:                63000
#  Thread:           1 Photon nr:                64000
#  Thread:           2 Photon nr:                65000
#  Thread:           0 Photon nr:                66000
#  Thread:           0 Photon nr:                67000
#  Thread:           1 Photon nr:                68000
#  Thread:           1 Photon nr:                69000
#  Thread:           0 Photon nr:                70000
#  Thread:           3 Photon nr:                71000
#  Thread:           3 Photon nr:                72000
#  Thread:           3 Photon nr:                73000
#  Thread:           2 Photon nr:                74000
#  Thread:           3 Photon nr:                75000
#  Thread:           0 Photon nr:                76000
#  Thread:           2 Photon nr:                77000
#  Thread:           1 Photon nr:                78000
#  Thread:           2 Photon nr:                79000
#  Thread:           2 Photon nr:                80000
#  Thread:           0 Photon nr:                81000
#  Thread:           1 Photon nr:                82000
#  Thread:           2 Photon nr:                83000
#  Thread:           1 Photon nr:                84000
#  Thread:           0 Photon nr:                85000
#  Thread:           0 Photon nr:                86000
#  Thread:           0 Photon nr:                87000
#  Thread:           0 Photon nr:                88000
#  Thread:           0 Photon nr:                89000
#  Thread:           1 Photon nr:                90000
#  Thread:           0 Photon nr:                91000
#  Thread:           2 Photon nr:                92000
#  Thread:           3 Photon nr:                93000
#  Thread:           0 Photon nr:                94000
#  Thread:           2 Photon nr:                95000
#  Thread:           3 Photon nr:                96000
#  Thread:           3 Photon nr:                97000
#  Thread:           3 Photon nr:                98000
#  Thread:           0 Photon nr:                99000
#  Thread:           1 Photon nr:               100000
#  Thread:           1 Photon nr:               101000
#  Thread:           1 Photon nr:               102000
#  Thread:           0 Photon nr:               103000
#  Thread:           0 Photon nr:               104000
#  Thread:           2 Photon nr:               105000
#  Thread:           1 Photon nr:               106000
#  Thread:           1 Photon nr:               107000
#  Thread:           3 Photon nr:               108000
#  Thread:           2 Photon nr:               109000
#  Thread:           3 Photon nr:               110000
#  Thread:           3 Photon nr:               111000
#  Thread:           3 Photon nr:               112000
#  Thread:           1 Photon nr:               113000
#  Thread:           2 Photon nr:               114000
#  Thread:           0 Photon nr:               115000
#  Thread:           3 Photon nr:               116000
#  Thread:           3 Photon nr:               117000
#  Thread:           2 Photon nr:               118000
#  Thread:           2 Photon nr:               119000
#  Thread:           3 Photon nr:               120000
#  Thread:           2 Photon nr:               121000
#  Thread:           3 Photon nr:               122000
#  Thread:           2 Photon nr:              9720000
#  Thread:           1 Photon nr:              9721000
#  Thread:           3 Photon nr:              9722000
#  Thread:           3 Photon nr:              9723000
#  Thread:           0 Photon nr:              9724000
#  Thread:           0 Photon nr:              9725000
#  Thread:           1 Photon nr:              9726000
#  Thread:           3 Photon nr:              9727000
#  Thread:           0 Photon nr:              9728000
#  Thread:           1 Photon nr:              9729000
#  Thread:           1 Photon nr:              9730000
#  Thread:           1 Photon nr:              9731000
#  Thread:           1 Photon nr:              9732000
#  Thread:           2 Photon nr:              9733000
#  Thread:           1 Photon nr:              9734000
#  Thread:           3 Photon nr:              9735000
#  Thread:           3 Photon nr:              9736000
#  Thread:           2 Photon nr:              9737000
#  Thread:           2 Photon nr:              9738000
#  Thread:           0 Photon nr:              9739000
#  Thread:           0 Photon nr:              9740000
#  Thread:           0 Photon nr:              9741000
#  Thread:           1 Photon nr:              9742000
#  Thread:           0 Photon nr:              9743000
#  Thread:           3 Photon nr:              9744000
#  Thread:           2 Photon nr:              9745000
#  Thread:           1 Photon nr:              9746000
#  Thread:           1 Photon nr:              9747000
#  Thread:           1 Photon nr:              9748000
#  Thread:           3 Photon nr:              9749000
#  Thread:           1 Photon nr:              9750000
#  Thread:           1 Photon nr:              9751000
#  Thread:           2 Photon nr:              9752000
#  Thread:           3 Photon nr:              9753000
#  Thread:           0 Photon nr:              9754000
#  Thread:           0 Photon nr:              9755000
#  Thread:           1 Photon nr:              9756000
#  Thread:           3 Photon nr:              9757000
#  Thread:           0 Photon nr:              9758000
#  Thread:           1 Photon nr:              9759000
#  Thread:           3 Photon nr:              9760000
#  Thread:           1 Photon nr:              9761000
#  Thread:           2 Photon nr:              9762000
#  Thread:           2 Photon nr:              9763000
#  Thread:           3 Photon nr:              9764000
#  Thread:           3 Photon nr:              9765000
#  Thread:           0 Photon nr:              9766000
#  Thread:           3 Photon nr:              9767000
#  Thread:           0 Photon nr:              9768000
#  Thread:           1 Photon nr:              9769000
#  Thread:           1 Photon nr:              9770000
#  Thread:           3 Photon nr:              9771000
#  Thread:           3 Photon nr:              9772000
#  Thread:           3 Photon nr:              9773000
#  Thread:           3 Photon nr:              9774000
#  Thread:           0 Photon nr:              9775000
#  Thread:           1 Photon nr:              9776000
#  Thread:           0 Photon nr:              9777000
#  Thread:           0 Photon nr:              9778000
#  Thread:           1 Photon nr:              9779000
#  Thread:           1 Photon nr:              9780000
#  Thread:           1 Photon nr:              9781000
#  Thread:           0 Photon nr:              9782000
#  Thread:           0 Photon nr:              9783000
#  Thread:           3 Photon nr:              9784000
#  Thread:           0 Photon nr:              9785000
#  Thread:           2 Photon nr:              9786000
#  Thread:           1 Photon nr:              9787000
#  Thread:           2 Photon nr:              9788000
#  Thread:           2 Photon nr:              9789000
#  Thread:           2 Photon nr:              9790000
#  Thread:           3 Photon nr:              9791000
#  Thread:           0 Photon nr:              9792000
#  Thread:           3 Photon nr:              9793000
#  Thread:           3 Photon nr:              9794000
#  Thread:           0 Photon nr:              9795000
#  Thread:           2 Photon nr:              9796000
#  Thread:           1 Photon nr:              9797000
#  Thread:           2 Photon nr:              9798000
#  Thread:           2 Photon nr:              9799000
#  Thread:           3 Photon nr:              9800000
#  Thread:           3 Photon nr:              9801000
#  Thread:           3 Photon nr:              9802000
#  Thread:           3 Photon nr:              9803000
#  Thread:           0 Photon nr:              9804000
#  Thread:           2 Photon nr:              9805000
#  Thread:           2 Photon nr:              9806000
#  Thread:           1 Photon nr:              9807000
#  Thread:           1 Photon nr:              9808000
#  Thread:           2 Photon nr:              9809000
#  Thread:           3 Photon nr:              9810000
#  Thread:           1 Photon nr:              9811000
#  Thread:           1 Photon nr:              9812000
#  Thread:           3 Photon nr:              9813000
#  Thread:           0 Photon nr:              9814000
#  Thread:           0 Photon nr:              9815000
#  Thread:           3 Photon nr:              9816000
#  Thread:           1 Photon nr:              9817000
#  Thread:           2 Photon nr:              9818000
#  Thread:           1 Photon nr:              9819000
#  Thread:           0 Photon nr:              9820000
#  Thread:           1 Photon nr:              9821000
#  Thread:           1 Photon nr:              9822000
#  Thread:           0 Photon nr:              9823000
#  Thread:           2 Photon nr:              9824000
#  Thread:           0 Photon nr:              9825000
#  Thread:           1 Photon nr:              9826000
#  Thread:           3 Photon nr:              9827000
#  Thread:           0 Photon nr:              9828000
#  Thread:           2 Photon nr:              9829000
#  Thread:           1 Photon nr:              9830000
#  Thread:           1 Photon nr:              9831000
#  Thread:           3 Photon nr:              9832000
#  Thread:           2 Photon nr:              9833000
#  Thread:           2 Photon nr:              9834000
#  Thread:           1 Photon nr:              9835000
#  Thread:           1 Photon nr:              9836000
#  Thread:           1 Photon nr:              9837000
#  Thread:           0 Photon nr:              9838000
#  Thread:           3 Photon nr:              9839000
#  Thread:           0 Photon nr:              9840000
#  Thread:           2 Photon nr:              9841000
#  Thread:           0 Photon nr:              9842000
#  Thread:           0 Photon nr:              9843000
#  Thread:           3 Photon nr:              9844000
#  Thread:           2 Photon nr:              9845000
#  Thread:           2 Photon nr:              9846000
#  Thread:           1 Photon nr:              9847000
#  Thread:           2 Photon nr:              9848000
#  Thread:           0 Photon nr:              9849000
#  Thread:           0 Photon nr:              9850000
#  Thread:           0 Photon nr:              9851000
#  Thread:           1 Photon nr:              9852000
#  Thread:           2 Photon nr:              9853000
#  Thread:           3 Photon nr:              9854000
#  Thread:           0 Photon nr:              9855000
#  Thread:           2 Photon nr:              9856000
#  Thread:           0 Photon nr:              9857000
#  Thread:           3 Photon nr:              9858000
#  Thread:           1 Photon nr:              9859000
#  Thread:           2 Photon nr:              9860000
#  Thread:           3 Photon nr:              9861000
#  Thread:           0 Photon nr:              9862000
#  Thread:           2 Photon nr:              9863000
#  Thread:           1 Photon nr:              9864000
#  Thread:           2 Photon nr:              9865000
#  Thread:           1 Photon nr:              9866000
#  Thread:           0 Photon nr:              9867000
#  Thread:           2 Photon nr:              9868000
#  Thread:           2 Photon nr:              9869000
#  Thread:           0 Photon nr:              9870000
#  Thread:           1 Photon nr:              9871000
#  Thread:           1 Photon nr:              9872000
#  Thread:           1 Photon nr:              9873000
#  Thread:           1 Photon nr:              9874000
#  Thread:           1 Photon nr:              9875000
#  Thread:           0 Photon nr:              9876000
#  Thread:           1 Photon nr:              9877000
#  Thread:           0 Photon nr:              9878000
#  Thread:           3 Photon nr:              9879000
#  Thread:           3 Photon nr:              9880000
#  Thread:           1 Photon nr:              9881000
#  Thread:           0 Photon nr:              9882000
#  Thread:           1 Photon nr:              9883000
#  Thread:           3 Photon nr:              9884000
#  Thread:           3 Photon nr:              9885000
#  Thread:           2 Photon nr:              9886000
#  Thread:           0 Photon nr:              9887000
#  Thread:           2 Photon nr:              9888000
#  Thread:           2 Photon nr:              9889000
#  Thread:           3 Photon nr:              9890000
#  Thread:           0 Photon nr:              9891000
#  Thread:           3 Photon nr:              9892000
#  Thread:           1 Photon nr:              9893000
#  Thread:           2 Photon nr:              9894000
#  Thread:           3 Photon nr:              9895000
#  Thread:           0 Photon nr:              9896000
#  Thread:           0 Photon nr:              9897000
#  Thread:           0 Photon nr:              9898000
#  Thread:           3 Photon nr:              9899000
#  Thread:           2 Photon nr:              9900000
#  Thread:           0 Photon nr:              9901000
#  Thread:           1 Photon nr:              9902000
#  Thread:           1 Photon nr:              9903000
#  Thread:           3 Photon nr:              9904000
#  Thread:           3 Photon nr:              9905000
#  Thread:           2 Photon nr:              9906000
#  Thread:           0 Photon nr:              9907000
#  Thread:           2 Photon nr:              9908000
#  Thread:           0 Photon nr:              9909000
#  Thread:           2 Photon nr:              9910000
#  Thread:           0 Photon nr:              9911000
#  Thread:           2 Photon nr:              9912000
#  Thread:           3 Photon nr:              9913000
#  Thread:           2 Photon nr:              9914000
#  Thread:           1 Photon nr:              9915000
#  Thread:           2 Photon nr:              9916000
#  Thread:           2 Photon nr:              9917000
#  Thread:           2 Photon nr:              9918000
#  Thread:           2 Photon nr:              9919000
#  Thread:           0 Photon nr:              9920000
#  Thread:           2 Photon nr:              9921000
#  Thread:           2 Photon nr:              9922000
#  Thread:           0 Photon nr:              9923000
#  Thread:           1 Photon nr:              9924000
#  Thread:           3 Photon nr:              9925000
#  Thread:           2 Photon nr:              9926000
#  Thread:           2 Photon nr:              9927000
#  Thread:           3 Photon nr:              9928000
#  Thread:           3 Photon nr:              9929000
#  Thread:           3 Photon nr:              9930000
#  Thread:           1 Photon nr:              9931000
#  Thread:           0 Photon nr:              9932000
#  Thread:           3 Photon nr:              9933000
#  Thread:           0 Photon nr:              9934000
#  Thread:           1 Photon nr:              9935000
#  Thread:           1 Photon nr:              9936000
#  Thread:           3 Photon nr:              9937000
#  Thread:           3 Photon nr:              9938000
#  Thread:           0 Photon nr:              9939000
#  Thread:           3 Photon nr:              9940000
#  Thread:           2 Photon nr:              9941000
#  Thread:           1 Photon nr:              9942000
#  Thread:           1 Photon nr:              9943000
#  Thread:           3 Photon nr:              9944000
#  Thread:           3 Photon nr:              9945000
#  Thread:           0 Photon nr:              9946000
#  Thread:           2 Photon nr:              9947000
#  Thread:           1 Photon nr:              9948000
#  Thread:           3 Photon nr:              9949000
#  Thread:           2 Photon nr:              9950000
#  Thread:           3 Photon nr:              9951000
#  Thread:           0 Photon nr:              9952000
#  Thread:           0 Photon nr:              9953000
#  Thread:           3 Photon nr:              9954000
#  Thread:           0 Photon nr:              9955000
#  Thread:           3 Photon nr:              9956000
#  Thread:           1 Photon nr:              9957000
#  Thread:           3 Photon nr:              9958000
#  Thread:           2 Photon nr:              9959000
#  Thread:           3 Photon nr:              9960000
#  Thread:           0 Photon nr:              9961000
#  Thread:           3 Photon nr:              9962000
#  Thread:           1 Photon nr:              9963000
#  Thread:           3 Photon nr:              9964000
#  Thread:           0 Photon nr:              9965000
#  Thread:           2 Photon nr:              9966000
#  Thread:           0 Photon nr:              9967000
#  Thread:           0 Photon nr:              9968000
#  Thread:           2 Photon nr:              9969000
#  Thread:           1 Photon nr:              9970000
#  Thread:           1 Photon nr:              9971000
#  Thread:           3 Photon nr:              9972000
#  Thread:           0 Photon nr:              9973000
#  Thread:           0 Photon nr:              9974000
#  Thread:           3 Photon nr:              9975000
#  Thread:           3 Photon nr:              9976000
#  Thread:           1 Photon nr:              9977000
#  Thread:           0 Photon nr:              9978000
#  Thread:           0 Photon nr:              9979000
#  Thread:           2 Photon nr:              9980000
#  Thread:           1 Photon nr:              9981000
#  Thread:           3 Photon nr:              9982000
#  Thread:           0 Photon nr:              9983000
#  Thread:           2 Photon nr:              9984000
#  Thread:           0 Photon nr:              9985000
#  Thread:           2 Photon nr:              9986000
#  Thread:           2 Photon nr:              9987000
#  Thread:           3 Photon nr:              9988000
#  Thread:           2 Photon nr:              9989000
#  Thread:           0 Photon nr:              9990000
#  Thread:           2 Photon nr:              9991000
#  Thread:           0 Photon nr:              9992000
#  Thread:           2 Photon nr:              9993000
#  Thread:           2 Photon nr:              9994000
#  Thread:           1 Photon nr:              9995000
#  Thread:           2 Photon nr:              9996000
#  Thread:           2 Photon nr:              9997000
#  Thread:           2 Photon nr:              9998000
#  Thread:           0 Photon nr:              9999000
#  Thread:           0 Photon nr:             10000000
#  Elapsed time:   12.087930908892304
#  Done with Bjorkman & Wood Monte Carlo simulation
#  Using the parallel version of RADMC-3D
#  Number of parallel threads used:            4
#  Average number of abs/scat events per photon package =    8.1274999999999993E-003
#  Average nr of times a photon stays in the same cell  =    2.3942050660581131E-006
#  Maximum nr of times a photon stayed in the same cell =            1
#  Saving results of thermal Monte Carlo
#  Done...

# %%
# check temperature (northern emisphere)
Ts=np.fromfile('./dust_temperature.bdat', count=gridmodel.Nr*gridmodel.Nphi*gridmodel.Nth+4, dtype=float)[4:].reshape( (gridmodel.Nphi, gridmodel.Nth, gridmodel.Nr))
plt.pcolormesh(gridmodel.redge, gridmodel.thedge[::-1], Ts[0,:gridmodel.Nth,:])
plt.xlabel('Radius [Rsun]')
plt.xscale('log')
plt.ylabel(r'Polar angle [rad]')
plt.colorbar(label='Temperature [K]')
plt.show()

# %% [markdown]
# # Let's define the gas now that we have the temperature

# %%
gas=disc2radmc.gas(gas_species=gas_species,
                         star=starmodel,
                         grid=gridmodel,
                         functions_sigma=[Sigma_all, Sigma_all], # surface density function for each gas species
                         pars_sigma=[par_sigma, par_sigma], # parameters for each gas species
                         Masses=Masses, # Total gas mass of each species
                         masses=masses, # molecular weights
                         h=h, # vertical aspect ratio
                         mu=mu, # mean molecular weight
                         turbulence=turbulence,
                         alpha_turb=alpha_turb,
                        )
gas.write_density()
gas.write_velocity()
gas.write_turbulence()
# Out:
# Use dust temperature

# %% [markdown]
# We can first make an image of 12CO 2-1 with `sim.simcube()`. For that we need to indicate which gas species we want (1=CO and 2=CI in this case) and the transition we are interested in. `sim.simcube()` allows to add background sources, fix the stellar flux and pad the final image as it was shown in the example for the dust (https://github.com/SebaMarino/disc2radmc/blob/main/docs/examples/Dust_model.ipynb)
#
# ### Note that the gas is assumed to be in LTE. Non-LTE is possible in RADMC3D, but it assumes optically thin emission

# %%
sim.simcube(dpc=dpc,
            imagename='12c16o', # name that the image will have
            mol=1,  # indicate which gas species
            line=2, # indicate which transition
            vmax=8, # maximum velocity in km/s
            Nnu=9,# number of channels
            Npix=Npix,
            dpix=dpix,
            inc=inc,
            PA=PA,
            tag=target,
            continuum_subtraction=True # whether you want to subtract the continuum estimated using the first and last channel.
           )
# Out:
# image size = 7.7e+02 au
# radmc3d image incl 45.00000  phi  0.00000 posang 0.00000 iline 2 imolspec 1 widthkms 8.00000  vkms 0.0 linenlam 9 npix 512  sizeau 768.00000  doppcatch noscat
#
#  ================================================================
#       WELCOME TO RADMC-3D: A 3-D CONTINUUM AND LINE RT SOLVER
#
#                           VERSION 2.0
#
#                 (c) 2008-2023 Cornelis Dullemond
#
#        Please feel free to ask questions. Also please report
#         bugs and/or suspicious behavior without hestitation.
#       The reliability of this code depends on your vigilance!
#                     dullemond@uni-heidelberg.de
#
#    To keep up-to-date with bug-alarms and bugfixes, follow the
#                      RADMC-3D code on github
#              https://github.com/dullemond/radmc3d-2.0
#
#               Please visit the RADMC-3D home page at
#   http://www.ita.uni-heidelberg.de/~dullemond/software/radmc-3d/
#  ================================================================
#
#  Number of processors:           96
#  Number of threads in use:            4
#  Note: T_gas taken to be equal to T_dust of dust species            1
#  Reading global frequencies/wavelengths...
#  Reading grid file and prepare grid tree...
#  Reading star data...
#  Note: Please be aware that you treat the star(s) as
#        point source(s) while using spherical coordinate mode.
#        Since R_*<<R_in this is probably OK, but if you want
#        to play safe, then set istar_sphere = 1 in radmc3d.inp.
#  Note: Star 1 is taken to be a blackbody star
#        at a temperature T = 5800. Kelvin
#  Grid information (current status):
#    We have 125000 branches, of which 125000 are actual grid cells.
#    ---> 100.000% mem use for branches, and 100.000% mem use for actual cells.
#    No grid refinement is active. The AMR tree is not allocated (this saves memory).
#  Reading the heat source spatial distribution...
#  Using mirror symmetry in equatorial plane, because max(theta)==pi/2.
#  Starting procedure for rendering image...
#    --> Including dust
#    --> Including lines
#        No gas continuum included...
#  Using Gaussian line profile
#  Reading line data...
#  ERROR during line reading: failed. Aborting.
# ERROR: RADMC3D Failed, no file generated

# %% [markdown]
# Let's see the resulting cube

# %%
fit1=pyfits.open('./images/image_12c16o_'+target+'.fits')
cube=fit1[0].data[0,:,:,:]
header1= fit1[0].header

Nchan=np.shape(cube)[0]

# let's calculate the velocities of each channel
ckms=299792.458 # km/s
f_line=230.538000 # GHz
df=float(header1['CDELT3'])/1.0e9 # GHz
k0=float(header1['CRPIX3'])
f0=float(header1['CRVAL3'])/1.0e9 - (k0-1)*df # GHz
fs=np.linspace(f0,f0+df*(Nchan-1),Nchan) #GHz
vs=-(fs-f_line)*ckms/f_line  # km/s

channels_plot=np.arange(9)
Nchan=len(channels_plot)
fig=plt.figure(figsize=(12,12))
for ichan in range(Nchan):
    axi=fig.add_subplot(331+ichan)
    axi.pcolormesh(cube[channels_plot[ichan],:,:], vmin=0., vmax=np.max(cube), cmap='Blues')
    axi.set_aspect('equal')
    axi.text(50,450, '%1.2f km/s'%vs[channels_plot[ichan]], color='black' )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 fit1=pyfits.open('./images/image_12c16o_'+target+'.fits')
#       2 cube=fit1[0].data[0,:,:,:]
#       3 header1= fit1[0].header
#
# File /data/cs1316/disc2radmc_models/.venv/lib/python3.10/site-packages/astropy/io/fits/hdu/hdulist.py:223, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#     220 if not name:
#     221     raise ValueError(f"Empty filename: {name!r}")
# --> 223 return HDUList.fromfile(
#     224     name,
#     225     mode,
#     226     memmap,
#     227     save_backup,
#     228     cache,
#     229     lazy_load_hdus,
#     230     ignore_missing_simple,
#     231     use_fsspec=use_fsspec,
#     232     fsspec_kwargs=fsspec_kwargs,
#     233     decompress_in_memory=decompress_in_memory,
#     234     **kwargs,
#     235 )
#
# File /data/cs1316/disc2radmc_models/.venv/lib/python3.10/site-packages/astropy/io/fits/hdu/hdulist.py:487, in HDUList.fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     468 @classmethod
#     469 def fromfile(
#     470     cls,
#    (...)
#     478     **kwargs,
#     479 ):
#     480     """
#     481     Creates an `HDUList` instance from a file-like object.
#     482
#    (...)
#     485     documentation for details of the parameters accepted by this method).
#     486     """
# --> 487     return cls._readfrom(
#     488         fileobj=fileobj,
#     489         mode=mode,
#     490         memmap=memmap,
#     491         save_backup=save_backup,
#     492         cache=cache,
#     493         ignore_missing_simple=ignore_missing_simple,
#     494         lazy_load_hdus=lazy_load_hdus,
#     495         **kwargs,
#     496     )
#
# File /data/cs1316/disc2radmc_models/.venv/lib/python3.10/site-packages/astropy/io/fits/hdu/hdulist.py:1169, in HDUList._readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#    1166 if fileobj is not None:
#    1167     if not isinstance(fileobj, _File):
#    1168         # instantiate a FITS file object (ffo)
# -> 1169         fileobj = _File(
#    1170             fileobj,
#    1171             mode=mode,
#    1172             memmap=memmap,
#    1173             cache=cache,
#    1174             use_fsspec=use_fsspec,
#    1175             fsspec_kwargs=fsspec_kwargs,
#    1176             decompress_in_memory=decompress_in_memory,
#    1177         )
#    1178     # The Astropy mode is determined by the _File initializer if the
#    1179     # supplied mode was None
#    1180     mode = fileobj.mode
#
# File /data/cs1316/disc2radmc_models/.venv/lib/python3.10/site-packages/astropy/io/fits/file.py:218, in _File.__init__(self, fileobj, mode, memmap, overwrite, cache, use_fsspec, fsspec_kwargs, decompress_in_memory)
#     216     self._open_fileobj(fileobj, mode, overwrite)
#     217 elif isinstance(fileobj, (str, bytes)):
# --> 218     self._open_filename(fileobj, mode, overwrite)
#     219 else:
#     220     self._open_filelike(fileobj, mode, overwrite)
#
# File /data/cs1316/disc2radmc_models/.venv/lib/python3.10/site-packages/astropy/io/fits/file.py:651, in _File._open_filename(self, filename, mode, overwrite)
#     648 ext = os.path.splitext(self.name)[1]
#     650 if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 651     self._file = open(self.name, IO_FITS_MODES[mode])
#     652     self.close_on_error = True
#     654 # Make certain we're back at the beginning of the file
#     655 # BZ2File does not support seek when the file is open for writing, but
#     656 # when opening a file for write, bz2.BZ2File always truncates anyway.
#
# FileNotFoundError: [Errno 2] No such file or directory: './images/image_12c16o_HDawesome.fits'

# %% [markdown]
# Finally, you can define more exotic vertical distributions. First let's change the aspect ratio $h$ as a function of $r$ such that
# $$ H(r) = h r_0 (r/r_0)^{\gamma}$$
# We will also make the disc more inclined to see the effect

# %%
# vertical parameters
h=0.05
r0=rc # reference radius
gamma=3.

gas=disc2radmc.gas(gas_species=gas_species,
                         star=starmodel,
                         grid=gridmodel,
                         functions_sigma=[Sigma_all, Sigma_all], # surface density function for each gas species
                         pars_sigma=[par_sigma, par_sigma], # parameters for each gas species
                         Masses=Masses, # Total gas mass of each species
                         masses=masses, # molecular weights
                         h=h, # vertical aspect ratio
                         r0=r0,
                         gamma=gamma,
                         mu=mu, # mean molecular weight
                         turbulence=turbulence,
                         alpha_turb=alpha_turb,
                        )
gas.write_density()
gas.write_velocity()
gas.write_turbulence()

# %%
### MAKE CUBE WITH HIGHER INCLINATION
sim.simcube(dpc=dpc,
            imagename='12c16o_2', # name that the image will have
            mol=1,  # indicate which gas species
            line=2, # indicate which transition
            vmax=8, # maximum velocity in km/s
            Nnu=9,# number of channels
            Npix=Npix,
            dpix=dpix,
            inc=90.,
            PA=PA,
            tag=target,
            continuum_subtraction=True # whether you want to subtract the continuum estimated using the first and last channel.
           )

fit1=pyfits.open('./images/image_12c16o_2_'+target+'.fits')
cube=fit1[0].data[0,:,:,:]
header1	= fit1[0].header

Nchan=np.shape(cube)[0]

# let's calculate the velocities of each channel
ckms=299792.458 # km/s
f_line=230.538000 # GHz
df=float(header1['CDELT3'])/1.0e9 # GHz
k0=float(header1['CRPIX3'])
f0=float(header1['CRVAL3'])/1.0e9 - (k0-1)*df # GHz
fs=np.linspace(f0,f0+df*(Nchan-1),Nchan) #GHz
vs=-(fs-f_line)*ckms/f_line  # km/s

channels_plot=np.arange(9)
Nchan=len(channels_plot)
fig=plt.figure(figsize=(12,12))
for ichan in range(Nchan):
    axi=fig.add_subplot(331+ichan)
    axi.pcolormesh(cube[channels_plot[ichan],:,:], vmin=0., vmax=np.max(cube), cmap='Blues')
    axi.set_aspect('equal')
    axi.text(50,450, '%1.2f km/s'%vs[channels_plot[ichan]], color='black' )
# Out:
# image size = 7.7e+02 au
# radmc3d image incl 90.00000  phi  0.00000 posang 0.00000 iline 2 imolspec 1 widthkms 8.00000  vkms 0.0 linenlam 9 npix 512  sizeau 768.00000  doppcatch noscat

# %% [markdown]
# We can even define functions for the vertical distribution that are different from a Gaussian, as long as they are correctly normalized and can be defined as a function of z and H. Note that in this case H is simply a reference height and it can be a constant or vary with r by changing `gamma`. The vertical distribution function (called `rhoz_exotic` below), needs to be in units of 1/au and normalized such that $\int_{-\infty}^{\infty} \rho_{z, \mathrm{exotic}}(z)dz =1$. This is because the actual density is defined as the product between the surface density and the vertical distribution function (here called rhoz_exotic).

# %%
def rhoz_exotic(z, H):
    return 0.5*( np.exp(-(z-2*H)**2.0/(2.0*(H/2)**2.0))/(np.sqrt(2.0*np.pi)*H/2)+np.exp(-(z+2*H)**2.0/(2.0*(H/2)**2.0))/(np.sqrt(2.0*np.pi)*H/2) )

# vertical parameters
h=0.05
r0=rc # reference radius
gamma=1.

gas=disc2radmc.gas(gas_species=gas_species,
                         star=starmodel,
                         grid=gridmodel,
                         functions_sigma=[Sigma_all, Sigma_all], # surface density function for each gas species
                         pars_sigma=[par_sigma, par_sigma], # parameters for each gas species
                         Masses=Masses, # Total gas mass of each species
                         masses=masses, # molecular weights
                         h=h, # vertical aspect ratio
                         r0=r0,
                         gamma=gamma,
                         mu=mu, # mean molecular weight
                         turbulence=turbulence,
                         alpha_turb=alpha_turb,
                         functions_rhoz=[rhoz_exotic,rhoz_exotic], # one for each gas species
                        )
gas.write_density()
gas.write_velocity()
gas.write_turbulence()
sim.simcube(dpc=dpc,
            imagename='12c16o_3', # name that the image will have
            mol=1,  # indicate which gas species
            line=2, # indicate which transition
            vmax=8, # maximum velocity in km/s
            Nnu=9,# number of channels
            Npix=Npix,
            dpix=dpix,
            inc=90.,
            PA=PA,
            tag=target,
            continuum_subtraction=True # whether you want to subtract the continuum estimated using the first and last channel.
           )

fit1=pyfits.open('./images/image_12c16o_3_'+target+'.fits')
cube=fit1[0].data[0,:,:,:]
header1	= fit1[0].header

Nchan=np.shape(cube)[0]

# let's calculate the velocities of each channel
ckms=299792.458 # km/s
f_line=230.538000 # GHz
df=float(header1['CDELT3'])/1.0e9 # GHz
k0=float(header1['CRPIX3'])
f0=float(header1['CRVAL3'])/1.0e9 - (k0-1)*df # GHz
fs=np.linspace(f0,f0+df*(Nchan-1),Nchan) #GHz
vs=-(fs-f_line)*ckms/f_line  # km/s

channels_plot=np.arange(9)
Nchan=len(channels_plot)
fig=plt.figure(figsize=(12,12))
for ichan in range(Nchan):
    axi=fig.add_subplot(331+ichan)
    axi.pcolormesh(cube[channels_plot[ichan],:,:], vmin=0., vmax=np.max(cube), cmap='Blues')
    axi.set_aspect('equal')
    axi.text(50,450, '%1.2f km/s'%vs[channels_plot[ichan]], color='black' )
# Out:
# Use dust temperature
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: reading gas temperature when emispheres are not mirrored is not implemented yet
